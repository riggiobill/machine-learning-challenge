# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Cleaned the data w/ sort and filter

df = pd.read_csv("processed_data.csv")
df.shape
# Out:
# (9564, 50)

# %% [markdown]
# # Select your features (columns)

# %%
print(df.columns)
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
## These rows just add to data noise and so the model will have a tighter focus without them

df = df.drop(columns=['rowid','kepid','kepoi_name','kepler_name','koi_disposition','koi_score','koi_tce_delivname'])

## Drop null values/columns
df = df.dropna(axis='columns', how='all')
df = df.dropna()
df.head()
# Out:
#   koi_pdisposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CANDIDATE              0              0              0
# 1        CANDIDATE              0              0              0
# 2   FALSE POSITIVE              0              1              0
# 3   FALSE POSITIVE              0              1              0
# 4        CANDIDATE              0              0              0
#
#    koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0              0    9.488036     2.780000e-05    -2.780000e-05   170.538750
# 1              0   54.418383     2.480000e-04    -2.480000e-04   162.513840
# 2              0   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 3              0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4              0    2.525592     3.760000e-06    -3.760000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# Show remaining features after filtering and dropna tasks

print(df.columns)
# Out:
# Index(['koi_pdisposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

# %%
y = df["koi_pdisposition"]
X = df.drop(columns=["koi_pdisposition"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.tail(5)
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1848              0              0              0              0   10.627887
# 3114              0              0              0              0   10.423677
# 870               0              0              0              0    1.922800
# 9138              0              1              0              0    1.072934
# 1580              0              0              0              0   31.782112
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 1848     8.220000e-05    -8.220000e-05   137.818430          0.006080
# 3114     7.170000e-06    -7.170000e-06   138.009041          0.000584
# 870      4.690000e-06    -4.690000e-06   134.501740          0.001990
# 9138     1.450000e-07    -1.450000e-07   132.293066          0.000109
# 1580     1.770000e-04    -1.770000e-04   134.864500          0.004780
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
y_train.shape
# Out:
# (6558,)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3380              0              0              0              0   56.391062
# 5360              0              1              0              0    2.192004
# 834               0              1              0              0    1.744101
# 7896              0              0              1              0   20.413812
# 2826              0              0              1              0    0.536335
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3380     4.840000e-03    -4.840000e-03   167.579000          0.113000
# 5360     1.460000e-06    -1.460000e-06   132.218114          0.000761
# 834      6.450000e-07    -6.450000e-07   134.508670          0.000314
# 7896     3.220000e-04    -3.220000e-04   148.509200          0.013300
# 2826     8.810000e-07    -8.810000e-07   131.714470          0.001350
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

# %%
from sklearn.preprocessing import MinMaxScaler

X_scale = MinMaxScaler().fit(X_train)
scaled_X_train = X_scale.transform(X_train)
scaled_X_test = X_scale.transform(X_test)
scaled_X_test
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.58909669, 0.80928728,
#         0.55789735],
#        [0.        , 0.        , 0.        , ..., 0.52956598, 0.32528598,
#         0.54062319],
#        [1.        , 0.        , 0.        , ..., 0.52391115, 0.38322744,
#         0.69873543],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.76285163, 0.8381738 ,
#         0.57062567],
#        [0.        , 0.        , 1.        , ..., 0.61831056, 0.32029931,
#         0.52822547],
#        [0.        , 1.        , 0.        , ..., 0.87532765, 0.64948715,
#         0.51243904]])

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {model1.score(X_train, y_train)}")
print(f"Testing Data Score: {model1.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.503354681305276
# Testing Data Score: 0.5036596523330283

# %%
## 0.50 is not particularly good - note this for later results

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

grid1 = GridSearchCV(model1, {'C': [1, 10], 'penalty': ["l1", "l2"]}, verbose=3)

# %%
# Train the model with GridSearch

grid1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] C=1, penalty=l1 .................................................
# [CV] ....................... C=1, penalty=l1, score=nan, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ....................... C=1, penalty=l1, score=nan, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ....................... C=1, penalty=l1, score=nan, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ....................... C=1, penalty=l1, score=nan, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ....................... C=1, penalty=l1, score=nan, total=   0.0s
# [CV] C=1, penalty=l2 .................................................
# [CV] ..................... C=1, penalty=l2, score=0.786, total=   0.1s
# ...

# %%
print(grid1.best_params_)
print(grid1.best_score_)
# Out:
# {'C': 1, 'penalty': 'l2'}
# 0.7737135123067478

# %%
grid1
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [1, 10], 'penalty': ['l1', 'l2']}, verbose=3)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'riggiobill_model1.sav'
joblib.dump(model1, filename)
# Out:
# ['riggiobill_model1.sav']
